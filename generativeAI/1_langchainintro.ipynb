# %%
import langchain
print(langchain.__version__)
# Out:
# 1.2.15

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GEMNI_API_KEY"]=os.getenv("GEMNI_API_KEY")

# %% [markdown]
# ## gen ai model with gemni model

# %%
from langchain.chat_models import init_chat_model

llm = init_chat_model(
    "gemini-2.5-flash",
    model_provider="google_genai", 
    google_api_key=os.getenv("GEMNI_API_KEY")
)
response = llm.invoke("Explain the concept of a neural network in simple terms.")
print(response.content)
# Out:
# Imagine trying to teach a computer to "think" or "learn" in a way that's a bit like how our own brains work. That's essentially what a neural network is!
#
# Here's a breakdown in simple terms:
#
# 1.  **Inspired by the Brain:**
#     *   Our brains are made of billions of tiny cells called **neurons**. These neurons are connected to each other and send signals back and forth.
#     *   A neural network is a computer program, or a model, that tries to mimic this structure using **artificial neurons** (often called "nodes" or "units").
#
# 2.  **The "Neurons" (Nodes):**
#     *   Think of each artificial neuron as a tiny processing unit.
#     *   It takes in some information (numbers).
#     *   It does a simple calculation with that information.
#     *   Based on its calculation, it decides whether to "activate" and pass its own information along to the next neurons.
#
# 3.  **Layers of Connections:**
#     *   These artificial neurons are organized into layers:
# ...
